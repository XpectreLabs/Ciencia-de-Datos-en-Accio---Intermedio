# %% [markdown]
# # Caso 1: Análisis del Impacto Económico del Cambio Climático
# ### Contexto
# Explorar cómo las emisiones de CO₂ afectan el PIB y la temperatura global utilizando datos históricos.
# ### Instrucciones
# 1. Realiza un Análisis Exploratorio de Datos (EDA):
#    - Identifica correlaciones entre emisiones de CO₂, temperatura y PIB.
#    - Grafica la evolución de las emisiones de CO₂ y el PIB a lo largo del tiempo.
# 2. Construye un reporte que incluya:
#    - Gráficas descriptivas de las relaciones entre las variables.
#    - Un análisis narrativo que explique los hallazgos.
# 3. Diseña un dashboard interactivo para visualizar los datos por país y año.

# %%
# Paso 1: Importar librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Paso 2: Cargar el dataset
url = 'https://example.com/climate_change_dataset.csv'  # Reemplaza con un dataset real
data = pd.read_csv(url)
print("Primeras filas del dataset:")
print(data.head())

# Paso 3: Explorar las columnas y la distribución de las variables
# Completa el análisis exploratorio inicial.

# %% [markdown]
# ### Paso 4: Crear visualizaciones
# - Grafica la evolución del PIB y las emisiones de CO₂ a lo largo del tiempo.
# - Usa gráficos de dispersión para analizar la relación entre temperatura y PIB.

# %% [markdown]
# ### Paso 5: Crear un dashboard interactivo
# - Diseña un dashboard que permita explorar las emisiones de CO₂ y el PIB por país y año.
# - Usa herramientas como Plotly o Dash para crear gráficos interactivos.

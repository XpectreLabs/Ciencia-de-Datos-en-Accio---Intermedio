# %% [markdown]
# # Caso 3: Análisis de Datos de Salud Pública Global
# ### Contexto
# Analizar los indicadores de salud pública como la mortalidad infantil, la esperanza de vida y el gasto en salud para identificar desigualdades globales.
# ### Instrucciones
# 1. Realiza un análisis exploratorio (EDA):
#    - Identifica patrones en la mortalidad infantil y el gasto en salud.
#    - Relaciona el gasto en salud con la esperanza de vida.
# 2. Construye un reporte que incluya:
#    - Visualizaciones claras y descriptivas.
#    - Un análisis narrativo de los hallazgos.
# 3. Diseña un dashboard interactivo que permita explorar los indicadores por región y año.

# %%
# Paso 1: Importar librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Paso 2: Cargar el dataset
url = 'https://example.com/global_health.csv'  # Reemplaza con un dataset real
data = pd.read_csv(url)
print("Primeras filas del dataset:")
print(data.head())

# Paso 3: Explorar las columnas y la distribución de las variables
# Completa el análisis exploratorio inicial.

# %% [markdown]
# ### Paso 4: Crear visualizaciones
# - Grafica la relación entre el gasto en salud y la esperanza de vida.
# - Usa gráficos de barras para comparar la mortalidad infantil entre regiones.
# - Analiza la evolución de la esperanza de vida a lo largo del tiempo.

# %% [markdown]
# ### Paso 5: Crear un dashboard interactivo
# - Diseña un dashboard que permita explorar los indicadores clave por regiones, años y otros filtros relevantes.
# - Usa herramientas como Plotly o Dash para crear gráficos interactivos.

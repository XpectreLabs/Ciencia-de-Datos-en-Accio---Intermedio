# %% [markdown]
# # Ejercicio: Construcción de Reportes Efectivos
# ### Objetivo
# Crear visualizaciones claras y explicativas que respalden conclusiones clave en un reporte.
# ### Instrucciones
# 1. Generar 3 visualizaciones utilizando un dataset ficticio de ventas.
# 2. Cada visualización debe incluir:
#    - Título descriptivo.
#    - Etiquetas en los ejes.
#    - Leyenda o anotaciones si es necesario.
# 3. Escribir un resumen breve (1-2 párrafos) que explique los hallazgos principales y su relevancia.

# %%
# Paso 1: Importar las librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Paso 2: Crear un dataset ficticio
data = pd.DataFrame({
    'Region': ['Norte', 'Sur', 'Este', 'Oeste'],
    'Ventas': [25000, 15000, 20000, 10000],
    'Crecimiento (%)': [5.2, 3.8, 4.5, 2.1]
})
print("Dataset cargado:")
print(data)

# Paso 3: Crear las visualizaciones
# Completa el código para generar un gráfico de barras que muestre las ventas por región.

# %% [markdown]
# ### Paso 4: Redactar un resumen
# Con base en las gráficas generadas, escribe un resumen explicando los hallazgos más importantes.
# - ¿Qué región tiene más ventas?
# - ¿Cuál tiene menor crecimiento?
# - ¿Qué acciones podrías recomendar con base en los datos?

# %% [markdown]
# # Ejercicio: Herramientas de Visualización Interactiva con Plotly
# ### Objetivo
# Crear gráficos interactivos utilizando la biblioteca Plotly para explorar datos de manera intuitiva.
# ### Instrucciones
# 1. Generar al menos 3 gráficos interactivos:
#    - Gráfico de líneas con evolución de datos temporales.
#    - Gráfico de dispersión mostrando la relación entre dos variables.
#    - Gráfico de barras comparando categorías.
# 2. Configurar etiquetas de los ejes y títulos.
# 3. Redactar un breve resumen de los insights obtenidos.

# %%
# Paso 1: Importar las librerías necesarias
import pandas as pd
import plotly.express as px

# Paso 2: Crear un dataset ficticio
data = pd.DataFrame({
    'Año': [2020, 2021, 2022, 2023],
    'Ventas': [20000, 25000, 30000, 35000],
    'Clientes': [150, 200, 250, 300],
    'Región': ['Norte', 'Sur', 'Este', 'Oeste']
})
print("Dataset cargado:")
print(data)

# Paso 3: Crear gráficos interactivos
# Completa el código para crear un gráfico de líneas que muestre la evolución de las ventas a lo largo de los años.

# %% [markdown]
# ### Paso 4: Resumen
# Con base en los gráficos creados, responde las siguientes preguntas:
# - ¿Qué año tuvo el mayor incremento en ventas?
# - ¿Qué región parece tener el mejor desempeño?
# - ¿Qué relación observas entre el número de clientes y las ventas?

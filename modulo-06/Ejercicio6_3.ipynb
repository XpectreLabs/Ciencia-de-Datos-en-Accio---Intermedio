# %% [markdown]
# # Ejercicio: Caso Práctico - Presentación de Hallazgos Clave
# ### Objetivo
# Sintetizar el proceso completo de un proyecto de ciencia de datos y presentar los hallazgos clave mediante gráficos y narrativa.
# ### Instrucciones
# 1. Usar el dataset proporcionado para realizar:
#    - Un análisis exploratorio (EDA).
#    - Construcción de al menos dos gráficos que muestren insights relevantes.
# 2. Redactar un reporte final con:
#    - Contexto y objetivo del análisis.
#    - Metodología empleada (limpieza, modelado, etc.).
#    - Conclusiones y recomendaciones basadas en los datos.
# 3. Presentar los hallazgos en un entorno profesional, como si se tratara de un reporte ejecutivo.

# %%
# Paso 1: Importar librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Paso 2: Cargar el dataset
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
data = pd.read_csv(url)
print("Primeras filas del dataset:")
print(data.head())

# Paso 3: Exploración de Datos
# Completa los pasos para analizar las columnas de interés (e.g., edad, tarifa, sobrevivencia).

# %% [markdown]
# ### Paso 4: Construcción de Gráficos
# Genera al menos dos gráficos que respondan preguntas como:
# - ¿Qué porcentaje de pasajeros sobrevivió?
# - ¿Cómo varía la tarifa promedio según la clase del pasajero?
# - ¿Existe una relación entre edad y sobrevivencia?

# %% [markdown]
# ### Paso 5: Redactar el Reporte Final
# Incluye:
# - **Contexto:** Breve descripción del dataset y el problema a resolver.
# - **Metodología:** Resumen de los pasos realizados.
# - **Resultados:** Insights obtenidos de los gráficos generados.
# - **Recomendaciones:** Propuestas basadas en los datos analizados.
